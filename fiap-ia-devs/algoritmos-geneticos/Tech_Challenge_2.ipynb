# %%
import random

# %%
class Produto:
    def __init__(self, nome, espaco, valor):
        self.nome = nome
        self.espaco = espaco
        self.valor = valor

# %%
class Individuo:
    def __init__(self, produtos, limite):
        self.produtos = produtos
        self.limite = limite
        self.cromossomo = [random.choice([0, 1]) for _ in range(len(produtos))]
        self.nota_avaliacao = self.avaliacao()
        self.espaco_usado = self.calcular_espaco()

    def avaliacao(self):
        soma_valores = 0
        soma_espacos = 0
        for i in range(len(self.cromossomo)):
            if self.cromossomo[i] == 1:
                soma_valores += self.produtos[i].valor
                soma_espacos += self.produtos[i].espaco
            if soma_espacos > self.limite:
                soma_valores = 1  # Penalização se exceder o limite
        return soma_valores

    def calcular_espaco(self):
        soma_espacos = 0
        for i in range(len(self.cromossomo)):
            if self.cromossomo[i] == 1:
                soma_espacos += self.produtos[i].espaco
        return soma_espacos

# %%
class AlgoritmoGenetico:
    def __init__(self, produtos, limite, tamanho_populacao, taxa_mutacao, geracoes):
        self.produtos = produtos
        self.limite = limite
        self.tamanho_populacao = tamanho_populacao
        self.taxa_mutacao = taxa_mutacao
        self.geracoes = geracoes
        self.populacao = [Individuo(produtos, limite) for _ in range(tamanho_populacao)]
        self.melhor_solucao = self.populacao[0]  # Inicializa com o primeiro indivíduo

    def ordena_populacao(self):
        self.populacao.sort(key=lambda x: x.nota_avaliacao, reverse=True)

    def seleciona_pai(self):
        soma_avaliacao = sum(ind.nota_avaliacao for ind in self.populacao)
        valor_sorteado = random.uniform(0, soma_avaliacao)
        soma = 0
        for i, ind in enumerate(self.populacao):
            soma += ind.nota_avaliacao
            if soma >= valor_sorteado:
                return i
        return len(self.populacao) - 1

    def crossover(self, pai1, pai2):
        corte = random.randint(1, len(pai1.cromossomo) - 1)
        filho1_cromossomo = pai1.cromossomo[:corte] + pai2.cromossomo[corte:]
        filho2_cromossomo = pai2.cromossomo[:corte] + pai1.cromossomo[corte:]
        return Individuo(self.produtos, self.limite), Individuo(self.produtos, self.limite)

    def mutacao(self, individuo):
        for i in range(len(individuo.cromossomo)):
            if random.random() < self.taxa_mutacao:
                individuo.cromossomo[i] = 1 - individuo.cromossomo[i] # Troca 0 por 1 ou 1 por 0
        individuo.nota_avaliacao = individuo.avaliacao()
        individuo.espaco_usado = individuo.calcular_espaco()

    def visualizar(self, geracao):
        print(f"\nGeração {geracao + 1}:")
        print(f"Melhor Nota: {self.populacao[0].nota_avaliacao:.2f}, Espaço Usado: {self.populacao[0].espaco_usado:.2f}")

    def visualizar_final(self):
        print(f"Melhor solução -> G:{self.geracoes} Valor:{self.melhor_solucao.nota_avaliacao:.2f} Espaço:{self.melhor_solucao.espaco_usado:.2f} Cromossomo:")
        print(self.melhor_solucao.cromossomo)
        for i in range(len(self.produtos)):
            if self.melhor_solucao.cromossomo[i] == 1:
                print(f"Nome: {self.produtos[i].nome} R${self.produtos[i].valor:.2f}")

    def resolver(self):
        for geracao in range(self.geracoes):
            self.ordena_populacao()
            self.visualizar(geracao)  # Imprime a melhor geração atual

            nova_populacao = []
            while len(nova_populacao) < self.tamanho_populacao:
                pai1 = self.seleciona_pai()
                pai2 = self.seleciona_pai()
                filhos = self.crossover(self.populacao[pai1], self.populacao[pai2])
                for filho in filhos:
                    self.mutacao(filho)
                    nova_populacao.append(filho)

            self.populacao = nova_populacao

            # Atualiza a melhor solução se necessário
            if self.populacao[0].nota_avaliacao > self.melhor_solucao.nota_avaliacao:
                self.melhor_solucao = self.populacao[0]

# %%
produtos = [
    Produto("Geladeira Dako", 1.5, 999.9),
    Produto("Iphone 6", 0.5, 2911.12),
    Produto("TV 50'", 0.8, 3999.9),
    Produto("TV 42'", 0.7, 2999.0),
    Produto("Notebook Dell", 1.2, 2499.9),
    Produto("Microondas Electrolux", 0.6, 308.66),
    Produto("Microondas LG", 0.6, 429.9),
    Produto("Microondas Panasonic", 0.5, 299.29),
    Produto("Notebook Lenovo", 1.1, 1999.9),
    Produto("Notebook Asus", 1.0, 3999.0)
]

limite = 2  # Limite de espaço em metros cúbicos
tamanho_populacao = 20
taxa_mutacao = 0.01
geracoes = 100

ag = AlgoritmoGenetico(produtos, limite, tamanho_populacao, taxa_mutacao, geracoes)
ag.resolver()

print("\nMelhor Solução Final:")
ag.visualizar_final()  # Imprime a melhor solução final
# Out:
# Geração 1:
# Melhor Nota: 3911.02, Espaço Usado: 2.00
#
# Geração 2:
# Melhor Nota: 2808.56, Espaço Usado: 1.80
#
# Geração 3:
# Melhor Nota: 3606.95, Espaço Usado: 1.80
#
# Geração 4:
# Melhor Nota: 1.00, Espaço Usado: 3.30
#
# Geração 5:
# Melhor Nota: 1037.85, Espaço Usado: 1.70
#
# Geração 6:
# Melhor Nota: 1.00, Espaço Usado: 3.20
#
# Geração 7:
# Melhor Nota: 729.19, Espaço Usado: 1.10
#
# Geração 8:
# Melhor Nota: 2808.56, Espaço Usado: 1.80
#
# Geração 9:
# Melhor Nota: 2429.80, Espaço Usado: 1.70
#
# Geração 10:
# Melhor Nota: 6340.02, Espaço Usado: 1.80
#
# Geração 11:
# Melhor Nota: 7209.41, Espaço Usado: 2.00
#
# Geração 12:
# Melhor Nota: 7998.90, Espaço Usado: 1.80
#
# Geração 13:
# Melhor Nota: 1037.85, Espaço Usado: 1.70
#
# Geração 14:
# Melhor Nota: 1.00, Espaço Usado: 4.10
#
# Geração 15:
# Melhor Nota: 4729.09, Espaço Usado: 1.90
#
# Geração 16:
# Melhor Nota: 4298.29, Espaço Usado: 1.50
#
# Geração 17:
# Melhor Nota: 1.00, Espaço Usado: 4.70
#
# Geração 18:
# Melhor Nota: 2929.80, Espaço Usado: 1.80
#
# Geração 19:
# Melhor Nota: 3307.66, Espaço Usado: 1.30
#
# Geração 20:
# Melhor Nota: 4299.19, Espaço Usado: 1.30
#
# Geração 21:
# Melhor Nota: 4307.66, Espaço Usado: 1.60
#
# Geração 22:
# Melhor Nota: 5999.80, Espaço Usado: 1.90
#
# Geração 23:
# Melhor Nota: 2929.80, Espaço Usado: 1.80
#
# Geração 24:
# Melhor Nota: 3737.56, Espaço Usado: 1.90
#
# Geração 25:
# Melhor Nota: 5999.80, Espaço Usado: 1.90
#
# Geração 26:
# Melhor Nota: 5498.90, Espaço Usado: 1.90
#
# Geração 27:
# Melhor Nota: 1.00, Espaço Usado: 5.60
#
# Geração 28:
# Melhor Nota: 7998.90, Espaço Usado: 1.80
#
# Geração 29:
# Melhor Nota: 7219.68, Espaço Usado: 1.90
#
# Geração 30:
# Melhor Nota: 4307.66, Espaço Usado: 1.60
#
# Geração 31:
# Melhor Nota: 6911.02, Espaço Usado: 1.30
#
# Geração 32:
# Melhor Nota: 3307.66, Espaço Usado: 1.30
#
# Geração 33:
# Melhor Nota: 1.00, Espaço Usado: 2.80
#
# Geração 34:
# Melhor Nota: 3999.90, Espaço Usado: 0.80
#
# Geração 35:
# Melhor Nota: 4429.80, Espaço Usado: 1.40
#
# Geração 36:
# Melhor Nota: 7298.19, Espaço Usado: 2.00
#
# Geração 37:
# Melhor Nota: 1.00, Espaço Usado: 5.20
#
# Geração 38:
# Melhor Nota: 6209.41, Espaço Usado: 1.70
#
# Geração 39:
# Melhor Nota: 1.00, Espaço Usado: 2.90
#
# Geração 40:
# Melhor Nota: 3999.90, Espaço Usado: 0.80
#
# Geração 41:
# Melhor Nota: 9910.02, Espaço Usado: 2.00
#
# Geração 42:
# Melhor Nota: 9910.02, Espaço Usado: 2.00
#
# Geração 43:
# Melhor Nota: 1.00, Espaço Usado: 3.60
#
# Geração 44:
# Melhor Nota: 3307.66, Espaço Usado: 1.30
#
# Geração 45:
# Melhor Nota: 1.00, Espaço Usado: 5.80
#
# Geração 46:
# Melhor Nota: 1.00, Espaço Usado: 2.30
#
# Geração 47:
# Melhor Nota: 1.00, Espaço Usado: 4.20
#
# Geração 48:
# Melhor Nota: 738.56, Espaço Usado: 1.20
#
# Geração 49:
# Melhor Nota: 429.90, Espaço Usado: 0.60
#
# Geração 50:
# Melhor Nota: 1.00, Espaço Usado: 4.10
#
# Geração 51:
# Melhor Nota: 738.56, Espaço Usado: 1.20
#
# Geração 52:
# Melhor Nota: 4307.66, Espaço Usado: 1.60
#
# Geração 53:
# Melhor Nota: 6998.00, Espaço Usado: 1.70
#
# Geração 54:
# Melhor Nota: 4299.19, Espaço Usado: 1.30
#
# Geração 55:
# Melhor Nota: 1.00, Espaço Usado: 6.40
#
# Geração 56:
# Melhor Nota: 1299.19, Espaço Usado: 2.00
#
# Geração 57:
# Melhor Nota: 4729.09, Espaço Usado: 1.90
#
# Geração 58:
# Melhor Nota: 5999.80, Espaço Usado: 1.90
#
# Geração 59:
# Melhor Nota: 6499.80, Espaço Usado: 2.00
#
# Geração 60:
# Melhor Nota: 4738.46, Espaço Usado: 2.00
#
# Geração 61:
# Melhor Nota: 1.00, Espaço Usado: 5.30
#
# Geração 62:
# Melhor Nota: 4299.19, Espaço Usado: 1.30
#
# Geração 63:
# Melhor Nota: 4428.90, Espaço Usado: 1.60
#
# Geração 64:
# Melhor Nota: 308.66, Espaço Usado: 0.60
#
# Geração 65:
# Melhor Nota: 1.00, Espaço Usado: 4.50
#
# Geração 66:
# Melhor Nota: 1.00, Espaço Usado: 6.40
#
# Geração 67:
# Melhor Nota: 7209.41, Espaço Usado: 2.00
#
# Geração 68:
# Melhor Nota: 3606.95, Espaço Usado: 1.80
#
# Geração 69:
# Melhor Nota: 4308.56, Espaço Usado: 1.40
#
# Geração 70:
# Melhor Nota: 4298.29, Espaço Usado: 1.50
#
# Geração 71:
# Melhor Nota: 6998.90, Espaço Usado: 1.50
#
# Geração 72:
# Melhor Nota: 3640.31, Espaço Usado: 1.60
#
# Geração 73:
# Melhor Nota: 4729.09, Espaço Usado: 1.90
#
# Geração 74:
# Melhor Nota: 2799.19, Espaço Usado: 1.70
#
# Geração 75:
# Melhor Nota: 1.00, Espaço Usado: 6.10
#
# Geração 76:
# Melhor Nota: 3728.19, Espaço Usado: 1.80
#
# Geração 77:
# Melhor Nota: 6218.78, Espaço Usado: 1.80
#
# Geração 78:
# Melhor Nota: 7998.90, Espaço Usado: 1.80
#
# Geração 79:
# Melhor Nota: 1037.85, Espaço Usado: 1.70
#
# Geração 80:
# Melhor Nota: 4429.80, Espaço Usado: 1.40
#
# Geração 81:
# Melhor Nota: 3640.31, Espaço Usado: 1.60
#
# Geração 82:
# Melhor Nota: 4429.80, Espaço Usado: 1.40
#
# Geração 83:
# Melhor Nota: 3737.56, Espaço Usado: 1.90
#
# Geração 84:
# Melhor Nota: 4428.90, Espaço Usado: 1.60
#
# Geração 85:
# Melhor Nota: 3728.19, Espaço Usado: 1.80
#
# Geração 86:
# Melhor Nota: 7340.92, Espaço Usado: 1.90
#
# Geração 87:
# Melhor Nota: 1.00, Espaço Usado: 5.30
#
# Geração 88:
# Melhor Nota: 3728.19, Espaço Usado: 1.80
#
# Geração 89:
# Melhor Nota: 4307.66, Espaço Usado: 1.60
#
# Geração 90:
# Melhor Nota: 6910.12, Espaço Usado: 1.50
#
# Geração 91:
# Melhor Nota: 7998.90, Espaço Usado: 1.80
#
# Geração 92:
# Melhor Nota: 1.00, Espaço Usado: 4.40
#
# Geração 93:
# Melhor Nota: 2308.56, Espaço Usado: 1.70
#
# Geração 94:
# Melhor Nota: 5498.90, Espaço Usado: 1.90
#
# Geração 95:
# Melhor Nota: 1.00, Espaço Usado: 3.60
#
# Geração 96:
# Melhor Nota: 3307.66, Espaço Usado: 1.30
#
# Geração 97:
# Melhor Nota: 607.95, Espaço Usado: 1.10
#
# Geração 98:
# Melhor Nota: 4428.90, Espaço Usado: 1.60
#
# Geração 99:
# Melhor Nota: 2429.80, Espaço Usado: 1.70
#
# Geração 100:
# Melhor Nota: 1.00, Espaço Usado: 2.80
#
# Melhor Solução Final:
# Melhor solução -> G:100 Valor:3307.66 Espaço:1.30 Cromossomo:
# [0, 0, 0, 1, 0, 1, 0, 0, 0, 0]
# Nome: TV 42' R$2999.00
# Nome: Microondas Electrolux R$308.66
